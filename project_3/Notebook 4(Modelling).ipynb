# %%
import pandas as pd
import seaborn as sns
import numpy as np

from nltk.tokenize import sent_tokenize, word_tokenize, RegexpTokenizer # RegexpTokenizer uses regex for tokenization
from nltk.stem import WordNetLemmatizer # for lemmatization
from nltk.stem.porter import PorterStemmer # for stemming
from nltk.corpus import stopwords # for stopwords removal
import nltk

from sklearn.model_selection import train_test_split, GridSearchCV, cross_val_score
from sklearn.pipeline import Pipeline # to compactly pack multiple modeling operations
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import MultinomialNB 
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import confusion_matrix, plot_confusion_matrix,ConfusionMatrixDisplay, accuracy_score, recall_score, precision_score, f1_score
from sklearn.ensemble import GradientBoostingClassifier, AdaBoostClassifier, VotingClassifier
from sklearn.datasets import make_classification

# Import CountVectorizer and TFIDFVectorizer from feature_extraction.text.
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer

#Import pycaret
from pycaret.classification import *

# %%
df = pd.read_csv('data/df_model.csv')

# %%
print(df.shape)
df.head()
# Out:
# (9667, 9)
#    Unnamed: 0                                              title  \
# 0           0  My new favorite 50 stars drink! Caffe misto wi...
# 1           1  How does your store handle partners buying mer...
# 2           3                 Looking for the gay male baristas?
# 3           4                         Reasons why I hate my job.
# 4           5  Sooo today somebody got a mocha cookie frappuc...
#
#    words_in_sentence  starbucks  \
# 0                 23          1
# 1                  8          1
# 2                  6          1
# 3                  6          1
# 4                 24          1
#
#                                        title_cleaned  \
# 0  my new favorite  stars drink caffe misto with ...
# 1  how does your store handle partners buying mer...
# 2                  looking for the gay male baristas
# 3                          reasons why i hate my job
# 4  sooo today somebody got a mocha cookie frappuc...
#
#                                           stem_words  \
# 0  ['my', 'new', 'favorit', 'star', 'drink', 'caf...
# 1  ['how', 'doe', 'your', 'store', 'handl', 'part...
# 2   ['look', 'for', 'the', 'gay', 'male', 'barista']
# 3        ['reason', 'whi', 'i', 'hate', 'my', 'job']
# 4  ['sooo', 'today', 'somebodi', 'got', 'a', 'moc...
#
#                                           stem_title  \
# 0  my new favorit star drink caff misto with oat ...
# 1    how doe your store handl partner buy merchandis
# 2                      look for the gay male barista
# 3                           reason whi i hate my job
# 4  sooo today somebodi got a mocha cooki frappuci...
#
#                                            tokenized  words_in_title
# 0  ['my', 'new', 'favorit', 'star', 'drink', 'caf...              20
# 1  ['how', 'doe', 'your', 'store', 'handl', 'part...               8
# 2   ['look', 'for', 'the', 'gay', 'male', 'barista']               6
# 3        ['reason', 'whi', 'i', 'hate', 'my', 'job']               6
# 4  ['sooo', 'today', 'somebodi', 'got', 'a', 'moc...              22
